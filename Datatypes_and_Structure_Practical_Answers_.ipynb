# %% [markdown]
# #Datatypes and Structure Practical Answers

# %%
#1️⃣ Write a code to create a string with your name and print it.
name = "Muskan"
print(name)
# Out:
# Muskan

# %%
#2️⃣ Write a code to find the length of the string "Hello World".
text = "Hello World"
print(len(text))
# Out:
# 11

# %%
#3️⃣ Write a code to slice the first 3 characters from the string "Python Programming".
s = "Python Programming"
print(s[:3])
# Out:
# Pyt

# %%
#4️⃣ Write a code to convert the string "hello" to uppercase.
text = "hello"
print(text.upper())
# Out:
# HELLO

# %%
#5️⃣ Write a code to replace the word "apple" with "orange" in the string "I like apple".
sentence = "I like apple"
print(sentence.replace("apple", "orange"))
# Out:
# I like orange

# %%
#6️⃣ Write a code to create a list with numbers 1 to 5 and print it.
numbers = [1, 2, 3, 4, 5]
print(numbers)
# Out:
# [1, 2, 3, 4, 5]

# %%
#7️⃣ Write a code to append the number 10 to the list [1, 2, 3, 4].
lst = [1, 2, 3, 4]
lst.append(10)
print(lst)
# Out:
# [1, 2, 3, 4, 10]

# %%
#8️⃣ Write a code to remove the number 3 from the list [1, 2, 3, 4, 5].
lst = [1, 2, 3, 4, 5]
lst.remove(3)
print(lst)
# Out:
# [1, 2, 4, 5]

# %%
#9️⃣ Write a code to access the second element in the list ['a', 'b', 'c', 'd'].
lst = ['a', 'b', 'c', 'd']
print(lst[1])#
# Out:
# b

# %%
#🔟 Write a code to reverse the list [10, 20, 30, 40, 50].
lst = [10, 20, 30, 40, 50]
lst.reverse()
print(lst)
# Out:
# [50, 40, 30, 20, 10]

# %%
#1️⃣1️⃣ Write a code to create a tuple with the elements 100, 200, 300 and print it.
t = (100, 200, 300)
print(t)
# Out:
# (100, 200, 300)

# %%
#12️⃣ Write a code to access the second-to-last element of the tuple ('red', 'green', 'blue', 'yellow').
colors = ('red', 'green', 'blue', 'yellow')
print(colors[-2])
# Out:
# blue

# %%
#13️⃣ Write a code to find the minimum number in the tuple (10, 20, 5, 15).
numbers = (10, 20, 5, 15)
print(min(numbers))
# Out:
# 5

# %%
#14️⃣ Write a code to find the index of the element "cat" in the tuple ('dog', 'cat', 'rabbit').
animals = ('dog', 'cat', 'rabbit')
print(animals.index("cat"))
# Out:
# 1

# %%
#15️⃣ Write a code to create a tuple containing three different fruits and check if "kiwi" is in it.
fruits = ("apple", "banana", "mango")
print("kiwi" in fruits)
# Out:
# False

# %%
#16️⃣ Write a code to create a set with the elements 'a', 'b', 'c' and print it.
s = {'a', 'b', 'c'}
print(s)
# Out:
# {'a', 'b', 'c'}

# %%
#17️⃣ Write a code to clear all elements from the set {1, 2, 3, 4, 5}.
s = {1, 2, 3, 4, 5}
s.clear()
print(s)
# Out:
# set()

# %%
#18️⃣ Write a code to remove the element 4 from the set {1, 2, 3, 4}.
s = {1, 2, 3, 4}
s.remove(4)
print(s)
# Out:
# {1, 2, 3}

# %%
#19️⃣ Write a code to find the union of two sets {1, 2, 3} and {3, 4, 5}.
a = {1, 2, 3}
b = {3, 4, 5}
print(a.union(b))
# Out:
# {1, 2, 3, 4, 5}

# %%
#20️⃣ Write a code to find the intersection of two sets {1, 2, 3} and {2, 3, 4}.
a = {1, 2, 3}
b = {2, 3, 4}
print(a.intersection(b))
# Out:
# {2, 3}

# %%
#21️⃣ Write a code to create a dictionary with the keys "name", "age", and "city", and print it.
info = {"name": "Muskan", "age": 20, "city": "Dhanbad"}
print(info)
# Out:
# {'name': 'Muskan', 'age': 20, 'city': 'Dhanbad'}

# %%
#22️⃣ Write a code to add a new key-value pair "country": "USA" to the dictionary {'name': 'John', 'age': 25}.
d = {'name': 'John', 'age': 25}
d["country"] = "USA"
print(d)
# Out:
# {'name': 'John', 'age': 25, 'country': 'USA'}

# %%
#23️⃣ Write a code to access the value associated with the key "name" in the dictionary {'name': 'Alice', 'age': 30}.
d = {'name': 'Alice', 'age': 30}
print(d["name"])
# Out:
# Alice

# %%
#24️⃣ Write a code to remove the key "age" from the dictionary {'name': 'Bob', 'age': 22, 'city': 'New York'}.
d = {'name': 'Bob', 'age': 22, 'city': 'New York'}
del d["age"]
print(d)
# Out:
# {'name': 'Bob', 'city': 'New York'}

# %%
#25️⃣ Write a code to check if the key "city" exists in the dictionary {'name': 'Alice', 'city': 'Paris'}.
d = {'name': 'Alice', 'city': 'Paris'}
print("city" in d)
# Out:
# True

# %%
#26️⃣ Write a code to create a list, a tuple, and a dictionary, and print them all.
my_list = [1, 2, 3]
my_tuple = (10, 20, 30)
my_dict = {"name": "Muskan", "age": 20}

print(my_list)
print(my_tuple)
print(my_dict)
# Out:
# [1, 2, 3]
# (10, 20, 30)
# {'name': 'Muskan', 'age': 20}

# %%
#27️⃣ Write a code to create a list of 5 random numbers between 1 and 100, sort it in ascending order, and print the result.
import random

numbers = [random.randint(1, 100) for _ in range(5)]
numbers.sort()
print(numbers)
# Out:
# [13, 42, 63, 63, 89]

# %%
#28️⃣ Write a code to create a list with strings and print the element at the third index.
lst = ["apple", "banana", "cherry", "orange", "kiwi"]
print(lst[3])
# Out:
# orange

# %%
#29️⃣ Write a code to combine two dictionaries into one and print the result.
d1 = {"a": 1, "b": 2}
d2 = {"c": 3, "d": 4}

combined = {**d1, **d2}
print(combined)
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %%
#30️⃣ Write a code to convert a list of strings into a set.
lst = ["apple", "banana", "apple", "mango"]
result = set(lst)
print(result)
# Out:
# {'mango', 'banana', 'apple'}
